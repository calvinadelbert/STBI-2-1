# %%
import numpy as np 
import pandas as pd 
import os
import re
import string
import numpy as np 
import random
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from tqdm import tqdm
import os
import nltk
import spacy
import random

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df = pd.read_csv("spam.csv", encoding="latin-1")

df = df.dropna(how="any", axis=1)
df.columns = ['target', 'message']

df.head()
# Out:
#   target                                            message
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['message_len'] = df['message'].apply(lambda x: len(x.split(' ')))
df.head()
# Out:
#   target                                            message  message_len
# 0    ham  Go until jurong point, crazy.. Available only ...           20
# 1    ham                      Ok lar... Joking wif u oni...            6
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...           28
# 3    ham  U dun say so early hor... U c already then say...           11
# 4    ham  Nah I don't think he goes to usf, he lives aro...           13

# %%
df['message_clean'] = df['message'].apply(clean_text)
df.head()
# Out:
#   target                                            message  message_len  \
# 0    ham  Go until jurong point, crazy.. Available only ...           20
# 1    ham                      Ok lar... Joking wif u oni...            6
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...           28
# 3    ham  U dun say so early hor... U c already then say...           11
# 4    ham  Nah I don't think he goes to usf, he lives aro...           13
#
#                                        message_clean
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in  a wkly comp to win fa cup final...
# 3        u dun say so early hor u c already then say
# 4  nah i dont think he goes to usf he lives aroun...

# %%
stop_words = stopwords.words('english')
more_stopwords = ['u', 'im', 'c']
stop_words = stop_words + more_stopwords

def remove_stopwords(text):
    text = ' '.join(word for word in text.split(' ') if word not in stop_words)
    return text
    
df['message_clean'] = df['message_clean'].apply(remove_stopwords)
df.head()
# Out:
#   target                                            message  message_len  \
# 0    ham  Go until jurong point, crazy.. Available only ...           20
# 1    ham                      Ok lar... Joking wif u oni...            6
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...           28
# 3    ham  U dun say so early hor... U c already then say...           11
# 4    ham  Nah I don't think he goes to usf, he lives aro...           13
#
#                                        message_clean
# 0  go jurong point crazy available bugis n great ...
# 1                              ok lar joking wif oni
# 2  free entry  wkly comp win fa cup final tkts  m...
# 3                      dun say early hor already say
# 4        nah dont think goes usf lives around though

# %%
stemmer = nltk.SnowballStemmer("english")

def stemm_text(text):
    text = ' '.join(stemmer.stem(word) for word in text.split(' '))
    return text

# %%
df['message_clean'] = df['message_clean'].apply(stemm_text)
df.head()
# Out:
#   target                                            message  message_len  \
# 0    ham  Go until jurong point, crazy.. Available only ...           20
# 1    ham                      Ok lar... Joking wif u oni...            6
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...           28
# 3    ham  U dun say so early hor... U c already then say...           11
# 4    ham  Nah I don't think he goes to usf, he lives aro...           13
#
#                                        message_clean
# 0  go jurong point crazi avail bugi n great world...
# 1                                ok lar joke wif oni
# 2  free entri  wkli comp win fa cup final tkts  m...
# 3                      dun say earli hor alreadi say
# 4          nah dont think goe usf live around though

# %%
def preprocess_data(text):
    # Clean puntuation, urls, and so on
    text = clean_text(text)
    # Remove stopwords
    text = ' '.join(word for word in text.split(' ') if word not in stop_words)
    # Stemm all the words in the sentence
    text = ' '.join(stemmer.stem(word) for word in text.split(' '))
    
    return text

# %%
df['message_clean'] = df['message_clean'].apply(preprocess_data)
df.head()
# Out:
#   target                                            message  message_len  \
# 0    ham  Go until jurong point, crazy.. Available only ...           20
# 1    ham                      Ok lar... Joking wif u oni...            6
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...           28
# 3    ham  U dun say so early hor... U c already then say...           11
# 4    ham  Nah I don't think he goes to usf, he lives aro...           13
#
#                                        message_clean
# 0  go jurong point crazi avail bugi n great world...
# 1                                ok lar joke wif oni
# 2  free entri  wkli comp win fa cup final tkts  m...
# 3                        dun say ear hor alreadi say
# 4          nah dont think goe usf live around though

# %%
df.head(-5)
# Out:
#      target                                            message  message_len  \
# 0       ham  Go until jurong point, crazy.. Available only ...           20
# 1       ham                      Ok lar... Joking wif u oni...            6
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...           28
# 3       ham  U dun say so early hor... U c already then say...           11
# 4       ham  Nah I don't think he goes to usf, he lives aro...           13
# ...     ...                                                ...          ...
# 5562    ham  Ok lor... Sony ericsson salesman... I ask shuh...           18
# 5563    ham                                Ard 6 like dat lor.            5
# 5564    ham  Why don't you wait 'til at least wednesday to ...           15
# 5565    ham                                       Huh y lei...            3
# 5566   spam  REMINDER FROM O2: To get 2.50 pounds free call...           28
#
#                                           message_clean
# 0     go jurong point crazi avail bugi n great world...
# 1                                   ok lar joke wif oni
# 2     free entri  wkli comp win fa cup final tkts  m...
# 3                           dun say ear hor alreadi say
# 4             nah dont think goe usf live around though
# ...                                                 ...
# 5562  ok lor soni ericsson salesman ask shuhui say q...
# 5563                                  ard  like dat lor
# 5564             dont wait til least wednesday see get
# 5565                                            huh lei
# 5566  remind  get  pound free call credit detail gre...
#
# [5567 rows x 4 columns]

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %% [markdown]
# # Document Expansion

# %%
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
def wordnet_doc_expansion(doc,k=3):
    ps = PorterStemmer()
    upd_doc = doc.split()
    synonyms =[]
    res=[w for w in upd_doc]
    for q in upd_doc:
        q_stem=ps.stem(q)
        for syn in wordnet.synsets(q_stem):
            for l in syn.lemmas():
                synonyms.append(l.name())
        synonyms=list(set(synonyms))
        synonyms=synonyms[:k]
        for w in synonyms:
            w_stem=ps.stem(w)
            if  w_stem!=q_stem:
                  res.append(w)
            synonyms=[]
    return ' '.join(res)

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# True

# %%
i = 'mean fat head'
upd_doca = ['mean', 'fat', 'head']
resa =[w for w in upd_doca]
resa
# Out:
# ['mean', 'fat', 'head']

# %%
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
ps = PorterStemmer()

ps.stem('meaning')
# Out:
# 'mean'

# %%
documents = df['message_clean']
docs_expansion = []
for i in documents:
  docs_expansion.append(wordnet_doc_expansion(i,1))
# docs_expansion = wordnet_doc_expansion(documents,2)

# %%
docs_expansion
# Out:
# ['go jurong point crazi avail bugi n great world la e buffet cine got amor wat crack direct help northward with_child earthly_concern Pelican_State east sideboard grow Cupid',
#  'ok lar joke wif oni all_right laugh Office_of_Naval_Intelligence',
#  'free entri wkli comp win fa cup final tkts may text fa receiv entri questionstd txt ratetc appli free_people advance transfuse terminal',
#  'dun say ear hor alreadi say grayish_brown pronounce auricle pronounce',
#  'nah dont think goe usf live around though imagine endure close_to',
#  'freemsg hey darl week word back id like fun still tb ok xxx std chgs send å£ rcv workweek binding same merriment inactive T.B. all_right 30 social_disease direct',
#  'even brother like speak treat like aid patent fifty-fifty comrade same verbalize goody same help manifest',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun bespeak go_under telephoner weigh supporter',
#  'winner valu network custom select receivea å£ prize reward claim call claim code valid hour success web customs_duty choice lever honor title call_option title codification minute',
#  'mobil month r entitl updat latest colour mobil camera free call mobil updat co free gas_constant late people_of_colour tv_camera free_people call_option Centennial_State free_people',
#  'gonna home soon dont want talk stuff anymor tonight k ive cri enough today abode before_long deficiency verbalize pig_out one_thousand adequate now',
#  'six chanc win cash pound txt send cost tsandc appli repli hl info sextet advance hard_currency British_pound_sterling direct toll hectolitre',
#  'urgent week free membership å£ prize jackpot txt word claim tc lccltd pobox pressing workweek free_people rank lever title atomic_number_43',
#  'ive search right word thank breather promi wont take help grant fulfil promi wonder bless time hunting rectify breathing_spell habit direct help_oneself Ulysses_Simpson_Grant satisfy sign prison_term',
#  'date sunday go_steady William_Ashley_Sunday',
#  'xxxmobilemovieclub use credit click wap link next txt messag click xxxmobilemovieclubcomnqjkgighjjgcbl habit acknowledgment penetrate connexion side_by_side penetrate',
#  'oh kim watch Ohio vigil',
#  'eh rememb spell name yes v naughti make v wet go nominate quintet build quintet plastered',
#  'fine thatåõ way feel thatåõ way gota b all_right agency spirit agency group_B',
#  'england v macedonia dont miss goalsteam news txt ur nation team eg england trywal scotland quintet Macedon misfire word land',
#  'serious spell name go nominate',
#  'i\x89û÷m go tri month ha ha joke crack laugh',
#  'ì pay first lar da stock comin earnings kickoff pedigree',
#  'aft finish lunch go str lor ard smth lor finish ur lunch alreadi close crack close',
#  'ffffffffff alright way meet sooner all_right agency conform_to rather',
#  'forc eat slice realli hungri tho suck mark get worri know sick turn pizza lol eat_up slash wet-nurse stain grow bang cast wrick',
#  'lol alway convinc',
#  'catch bus fri egg make tea eat mom left dinner feel love apprehension testis build teatime eat_up momma remaining spirit bang',
#  'back amp pack car ill let know room binding coterie elevator_car ominous Army_of_the_Righteous bang elbow_room',
#  'ahhh work vagu rememb feel like lol oeuvre spirit same',
#  'wait still clear sure sarcast x doesnt want live us delay inactive clear_up for_sure go deficiency endure U.S.A.',
#  'yeah got v apologet n fallen actin like spoilt child got caught till wont go bad cheer yea grow quintet northward hang same muff shaver grow catch money_box habit crack jolly_along',
#  'k tell anyth one_thousand separate',
#  'fear faint housework quick cuppa veneration feeble',
#  'thank subscript rington uk mobil charg å£ plea confirm repli yes repli charg inferior supplication substantiate',
#  'yup ok go home look time msg ì xuhui go learn may lesson all_right crack abode flavor prison_term monosodium_glutamate crack memorize',
#  'oop ill let know roommat done ominous Army_of_the_Righteous bang suffice',
#  'see letter b car examine alphabetic_character group_B elevator_car',
#  'anyth lor decid',
#  'hello saturday go text see youd decid anyth tomo tri invit anyth how-do-you-do Sabbatum crack examine',
#  'pls go ahead watt want sure great weekend abiola crack leading W deficiency for_sure with_child',
#  'forget tell want need crave love sweet arabian steed mmmmmm yummi draw_a_blank separate deficiency motive bang dessert Arab',
#  'rodger burn msg tri call repli sms free nokia mobil free camcord plea call deliveri tomorrow burn_down monosodium_glutamate call_option samarium free_people free_people supplication call_option',
#  'see examine',
#  'great hope like man well endow ltgt inch with_child desire same humanity intimately empower edge',
#  'callsmessagesmiss call call_option',
#  'didnt get hep b immuni nigeria grow group_B',
#  'fair enough anyth go sightly adequate crack',
#  'yeah hope tyler cant could mayb ask around bit yea desire President_Tyler cant_over necessitate close_to bite',
#  'dont know stubborn didnt even want go hospit kept tell mark weak sucker hospit weak sucker bang refractory fifty-fifty deficiency crack unbroken separate stain imperfect chump imperfect chump',
#  'think first time saw class imagine kickoff prison_term examine course_of_instruction',
#  'gram usual run like ltgt half eighth smarter though get almost whole second gram ltgt gm endure same one-half 8th chic grow most solid indorsement gm',
#  'k fyi x ride ear tomorrow morn hes crash place tonight one_thousand go devolve_on auricle helium break_apart station',
#  'wow never realiz embarass accomod thought like sinc best could alway seem happi cave sorri didnt dont give sorri offer sorri room embarass belly_laugh imagine same Charles_Herbert_Best appear spring go elbow_room',
#  'sms ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end repli end sptv samarium atomic_number_89 Modern Garden_State get_at bolshy extension wager field_hockey discipline wrong terminate terminate',
#  'know mallika sherawat yesterday find lturlgt bang witness',
#  'congrat year special cinema pass call suprman v etc free dont miss twelvemonth limited go_past call_option quintet free_people misfire',
#  'sorri ill call later meet ominous call_option subsequently conform_to',
#  'tell reach separate get_to',
#  'yesgauti sehwag odi seri',
#  'gonna pick burger way home cant even move pain kill pickax Warren_Burger agency abode cant_over fifty-fifty act infliction',
#  'ha ha ha good joke girl situat seeker just laugh little_girl',
#  'part check iq separate check_up_on I.Q.',
#  'sorri roommat took forev ok come direct all_right fall',
#  'ok lar doubl check wif da hair dresser alreadi said wun cut v short said cut look nice all_right check_up_on fuzz aforementioned abbreviate quintet brusque aforementioned abbreviate flavor prissy',
#  'valu custom plea advi follow recent review mob award å£ bonus prize call customs_duty supplication watch_over Holocene reexamine jam accolade lever call_option',
#  'today song dedic day song dedic send ur valuabl frnds first rpli now call call direct kickoff',
#  'urgent ur award complimentari trip eurodisinc trav å£ claim txt dis £ pressing accolade trip-up title',
#  'hear new divorc barbi come ken stuff get_a_line Modern fall cognizance pig_out',
#  'plane give month end aeroplane spring terminate',
#  'wah lucki man save money hee humanity write',
#  'finish class close course_of_instruction',
#  'hi babe home wanna someth xx baby abode twenty',
#  'kkwhere youhow perform do',
#  'call call_option',
#  'wait machan call free delay call_option free_people',
#  'cool gentleman treat digniti respect nerveless valet goody regard',
#  'like peopl much shi pa same a_lot protactinium',
#  'oper ltgt',
#  'still look job much tas earn inactive flavor subcontract a_lot atomic_number_73 pull_in',
#  'sorri ill call later ominous call_option subsequently',
#  'k call ah one_thousand call_option',
#  'ok way home hi hi all_right agency abode',
#  'place man station humanity',
#  'yup next stop side_by_side blockade',
#  'call later dont network urgnt sms call_option subsequently web samarium',
#  'real get yo need ticket one jacket done alreadi use multi real_number grow motive fine unrivaled crown suffice habit',
#  'yes start send request make pain came back back bed doubl coin factori gotta cash nitro kickoff direct bespeak build infliction fall binding binding bang mint hard_currency',
#  'realli still tonight babe inactive baby',
#  'ela kanoil download come wen ur free fall free_people',
#  'yeah don\x89û÷t stand close tho you\x89û÷ll catch someth yea endure confining apprehension',
#  'sorri pain ok meet anoth night spent late afternoon casualti mean havent done includ time sheet sorri infliction all_right conform_to washed-out recently entail suffice prison_term tack',
#  'smile pleasur smile pain smile troubl pour like rain smile hurt smile becoz someon still love see smile grinning grinning infliction grinning same rain_down grinning pain grinning inactive bang examine grinning',
#  'plea call custom servic repr guarant å£ cash å£ prize supplication call_option customs_duty hard_currency lever',
#  'havent plan buy later check alreadi lido got show e afternoon finish work alreadi contrive corrupt subsequently check_up_on grow demonstrate east close oeuvre',
#  'free rington wait collect simpli text password mix verifi get usher britney fml free_people delay word grow James_Ussher',
#  'watch telugu moviewat abt vigil',
#  'see finish load loan pay examine close lade loanword earnings',
#  'hi wk ok hol yes bit run forgot hairdress appoint four need get home n shower beforehand caus prob u ham all_right bite endure draw_a_blank nominate motive grow abode northward cascade overplay',
#  'plea dont text anymor noth el say supplication elevated_railroad pronounce',
#  'okay name ur price long legal wen pick ave x xx all_right nominate toll farsighted pickax go twenty',
#  'still look car buy gone drive test yet inactive flavor elevator_car corrupt endure force examine heretofore',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun bespeak go_under telephoner weigh supporter',
#  'wow right didnt mean guess gave boston men chang search locat nyc someth chang cuz signin page still say boston belly_laugh rectify entail guesswork move_over Hub_of_the_Universe humanity Chang_Jiang hunting Chang_Jiang varlet inactive pronounce Hub_of_the_Universe',
#  'umma life vava umma love lot dear Islamic_Ummah life_story Islamic_Ummah bang dish_out',
#  'thank lot wish birthday thank make birthday truli memor dish_out regard build',
#  'aight ill hit get cash ominous bang grow hard_currency',
#  'would ip address test consid comput isnt minecraft server informatics direct examine waiter',
#  'know grumpi old peopl mom like better lie alway one play joke bang one-time momma same punter lie_down unrivaled wager laugh',
#  'dont worri guess hes busi guesswork helium',
#  'plural noun research inquiry',
#  'go dinnermsg crack',
#  'ok wif cos like tri new thing scare dun like mah cos said loud all_right Centennial_State same Modern panic_attack grayish_brown same Centennial_State aforementioned brassy',
#  'gent tri contact last weekend draw show å£ prize guarant call claim code valid adjoin endure force demonstrate lever call_option title codification',
#  'wa ur openin sentenc formal anyway fine juz tt eatin much n puttin weighthaha anythin special happen conventional in_any_case all_right ephemeris_time a_lot northward limited materialise',
#  'enter cabin pa said happi bday boss felt special askd lunch lunch invit apart went get_in protactinium aforementioned political_boss mat_up limited asunder endure',
#  'winner special select receiv å£ holiday flight inc speak live oper claim success limited choice escape verbalize endure title',
#  'goodo yes must speak friday eggpotato ratio tortilla need mustiness verbalize Fri motive',
#  'hmmmi uncl inform hes pay school direct pls buy food helium earnings school_day corrupt',
#  'privat account statement show unredeem bonus point claim call identifi code expir invoice assertion demonstrate direct title call_option codification',
#  'urgent mobil award å£ bonus caller prize final tri contact call landlin pressing accolade telephoner lever terminal adjoin call_option',
#  'new address applespairs malarki Modern direct',
#  'today voda number end select receiv award match plea call quot claim code standard rate app now act terminate choice accolade mates supplication call_option title codification measure',
#  'go sao mu today done crack now suffice',
#  'ìï predict wat time ìll finish buy forecast prison_term close corrupt',
#  'good stuff just pig_out',
#  'knowyetund hasnt sent money yet sent text bother send dont involv anyth shouldnt impo anyth first place apolog direct heretofore direct hassle direct kickoff station',
#  'room elbow_room',
#  'hey girl r hope r well del r bak long time give call sum time lucyxx little_girl gas_constant desire gas_constant intimately gas_constant farsighted prison_term spring call_option nub prison_term',
#  'kkhow much cost a_lot toll',
#  'home abode',
#  'dear call tmorrowpl accomod call_option',
#  'first answer question kickoff solution doubtfulness',
#  'sunshin quiz wkli q win top soni dvd player know countri algarv txt ansr å£ sptyron test advance superlative thespian bang',
#  'want get laid tonight want real dog locat sent direct ur mob join uk largest dog network bt txting gravel nt deficiency grow deficiency real_number blackguard direct jam conjoin with_child blackguard web get_at',
#  'haf msn yijuehotmailcom',
#  'call meet call_option conform_to',
#  'check room befor activ check_up_on elbow_room',
#  'youll rcv msgs chat svc free hardcor servic text go get noth must age verifi yr network tri monosodium_glutamate free_people crack grow mustiness get_on twelvemonth web',
#  'got lazi type forgot ì lect saw pouch like v nice grow typewrite draw_a_blank examine bulge same quintet prissy',
#  'k text way one_thousand agency',
#  'sir wait mail delay chain_mail',
#  'swt thought nver get tire littl thing lovabl person cozsomtim littl thing occupi biggest part heart gud imagine grow fag somebody self-aggrandizing separate nub',
#  'know pls open back bang binding',
#  'yes see ya dot examine back_breaker',
#  'staff name take class us stave nominate direct course_of_instruction U.S.A.',
#  'freemsg havent repli text randi sexi femal live local luv hear netcollex ltd per msg repli stop end endure topical_anaesthetic get_a_line monosodium_glutamate blockade terminate',
#  'ummmawil call check inour life begin qatar pls pray hard call_option check_up_on life_story Katar_Peninsula difficult',
#  "ki delet contact ch'i adjoin",
#  'sindu got job birla soft grow subcontract piano',
#  'wine flow never vino current',
#  'yup thk cine better cos need go plaza mah punter Centennial_State motive crack shopping_center',
#  'ok ur typic repli all_right emblematic',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press copi friend callertun bespeak go_under telephoner weigh supporter',
#  'everywh dirt floor window even shirt sometim open mouth come flow dream world without half chore time joy lot tv show ill see guess like thing must exist like rain hail mist time done becom one grease base windowpane fifty-fifty lip fall current woolgather earthly_concern one-half task prison_term dish_out telly demonstrate ominous examine guesswork same mustiness same rain_down herald cloud prison_term suffice unrivaled',
#  'aaooooright work oeuvre',
#  'leav hous',
#  'hello love get interview today happi good boy think mear miss how-do-you-do bang grow now just imagine misfire',
#  'custom servic annonc new year deliveri wait plea call arrang deliveri customs_duty Modern twelvemonth delay supplication call_option',
#  'winner special select receiv å£ cash holiday flight inc speak live oper claim success limited choice hard_currency escape verbalize endure title',
#  'keep safe need miss alreadi envi everyon see real life keep_open rubber motive misfire examine real_number life_story',
#  'new car hous parentsi new job hand Modern elevator_car Modern subcontract script',
#  'love excit day spend make happi bang pass build',
#  'pls stop bootyd invit friend repli see stop send stop frnd blockade supporter examine blockade direct blockade',
#  'bangbab ur order way receiv servic msg download ur content goto wap bangb tv ur mobil internetserv menu say agency monosodium_glutamate mental_object telly card',
#  'place ur point e cultur modul alreadi station direct east',
#  'urgent tri contact last weekend draw show å£ prize guarant call claim code valid pressing adjoin endure force demonstrate lever call_option title codification',
#  'hi frnd best way avoid missunderstd wit belov one Charles_Herbert_Best agency quash card unrivaled',
#  'great escap fanci bridg need lager see tomo with_child motive lager_beer examine',
#  'yes complet formclark also utter wast likewise staring',
#  'sir need axi bank account bank address motive money_box invoice money_box direct',
#  'hmmm thk sure got time hop ard ya go free abt muz call discuss liao for_sure grow prison_term record_hop crack free_people call_option talk_over Liao_dynasty',
#  'time come later prison_term fall subsequently',
#  'bloodi hell cant believ forgot surnam mr ill give clue spanish begin sin cant_over draw_a_blank ominous spring Spanish_people',
#  'well gonna finish bath goodfin night intimately close bathtub',
#  'let know youv got money carlo make call Army_of_the_Righteous bang grow build call_option',
#  'still go mall inactive crack shopping_center',
#  'turn friend stay whole show wont back til ltgt feel free go ahead smoke ltgt worth wrick supporter stoppage solid demonstrate habit binding spirit free_people crack leading bullet',
#  'text doesnt repli let know log Army_of_the_Righteous bang logarithm',
#  'hi spoke maneesha v wed like know satisfi experi repli toll free yes rung quintet conjoin same bang free_people',
#  'lift hope offer money need especi end month approach hurt studi anyway weekend wind desire go motive terminate overture pain in_any_case',
#  'lol trust desire',
#  'ok gentleman treat digniti respect all_right valet goody regard',
#  'guy close laugh_at confining',
#  'go noth greatbi crack',
#  'hello handsom find job lazi work toward get back net mummi boytoy miss how-do-you-do witness subcontract oeuvre grow binding web misfire',
#  'haha awesom minut',
#  'plea call custom servic repr freephon guarant å£ cash å£ prize supplication call_option customs_duty hard_currency lever',
#  'got xmas radio time get grow prison_term grow',
#  "jus reach home go bath first sis use net tell finish k get_to abode crack bathtub kickoff Systeme_International_d'Unites habit web separate close one_thousand",
#  'uniqu enough find august adequate witness venerable',
#  'sorri ive join leagu peopl dont keep touch mean great deal friend time even great person cost great week conjoin keep_open hint entail with_child grapple supporter prison_term fifty-fifty with_child somebody toll with_child workweek',
#  'hi final complet cour terminal',
#  'stop howev suggest stay someon abl give everi stool blockade indicate stoppage spring throne',
#  'hope youv settl new school year wishin day desire Modern school_day twelvemonth',
#  'gud mrng dear hav nice day prissy',
#  'got person stori grow somebody',
#  'hamster dead hey tmr meet orchard mrt beat conform_to grove',
#  'hi kate even hope see tomorrow bit bloodi babyjontet txt back xxx fifty-fifty desire examine bite binding 30',
#  'found enc ltgt witness',
#  'sent ltgt buck direct',
#  'hello darlin ive finish colleg txt finish love kate xxx how-do-you-do close close bang 30',
#  'account refil success inr ltdecimalgt keralacircl prepaid account balanc rs ltdecimalgt transact id kr ltgt invoice achiever postpaid invoice gas_constant krypton',
#  'goodmorn sleep ga nap Georgia',
#  'call alter ok call_option spay all_right',
#  'ìï say like dat dun buy ericsson oso cannot oredi lar pronounce same grayish_brown corrupt',
#  'enter cabin pa said happi bday boss felt special askd lunch lunch invit apart went get_in protactinium aforementioned political_boss mat_up limited asunder endure',
#  'aight yo dat straight dogg direct',
#  'plea give us connect today ltdecimalgt refund bill supplication spring U.S.A. tie_in now repay greenback',
#  'shoot big load get readi buck self-aggrandizing lade grow',
#  'bruv hope great break reward semest desire with_child happy_chance honor',
#  'home alway chat abode',
#  'kkgoodstudi well intimately',
#  'yup ì noe leh',
#  'sound great home levelheaded with_child abode',
#  'final match head toward draw predict terminal mates direct force forecast',
#  "tire havent slept well past night fag catch_some_Z's intimately past_tense",
#  'easi ahsen got select mean good grow choice entail just',
#  'take exam march direct test parade',
#  'yeah think use gt atm regist sure anyway help let know sure readi yea imagine habit standard_atmosphere for_sure in_any_case help_oneself Army_of_the_Righteous bang for_sure',
#  'ok prob take ur time all_right direct prison_term',
#  'os call ubandu run without instal hard diskyou use os copi import file system give repair shop atomic_number_76 call_option endure difficult habit atomic_number_76 file_cabinet organisation spring amend buy_at',
#  'sorri ill call later ominous call_option subsequently',
#  'say leh cour noth happen lar say v romant jus bit lor thk e nite sceneri nice leh pronounce materialise pronounce quintet bite east prissy',
#  'new mobil must go txt nokia collect todayfrom å£ Modern mustiness crack',
#  'would realli appreci call need someon talk call_option motive verbalize',
#  'meet ur dream partner soon ur career flyng start find free txt horo follow ur star sign e g horo ari conform_to woolgather spouse before_long life_history kickoff witness free_people watch_over wiz planetary_house east gm',
#  'hey compani elama po mudyadhu United_States_Post_Office',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happi morn life_story stern direct test life_story kickoff direct test',
#  'dear good morn just',
#  'get gandhipuram walk cross cut road right side ltgt street road turn first right grow walk_of_life crabbed abbreviate rectify incline wrick kickoff rectify',
#  'dear go rubber place crack station',
#  'sorri batteri die yeah fail yea',
#  'yesher tv alway avail work place telly help oeuvre station',
#  'text meet someon sexi today find date even flirt join repli name age eg sam msg recdthirtyeight penc conform_to now witness go_steady fifty-fifty coquetry conjoin nominate get_on monosodium_glutamate',
#  'print oh ltgt come upstair Ohio fall',
#  'ill littl closer like bus stop street ominous confining same blockade',
#  'youwhen wil reach get_to',
#  'new theori argument win situat lose person dont argu ur friend kick amp say alway correct Modern contention advance suffer somebody supporter bang pronounce discipline',
#  'secret admir look make contact ufind rreveal think ur specialc mystical flavor build adjoin imagine',
#  'tomarrow final hear laptop case cant terminal get_a_line pillowcase cant_over',
#  'pleassssssseeee tel v avent done sportsx quintet suffice',
#  'okay shine meant sign sound better all_right gleam think planetary_house levelheaded punter',
#  'although told dat baig face watch realli like e watch gave cos fr thanx everyth dat uve done today touch separate cheek vigil same east vigil move_over Centennial_State atomic_number_87 suffice now hint',
#  'dont rememb old commerci one-time',
#  'late said websit didnt dont slipper recently aforementioned carpet_slipper',
#  'ask call ok necessitate call_option all_right',
#  'kalli wont bat inning habit cricket_bat frame',
#  'didnt work oh ok goodnight ill fix readi time wake dear miss good night sleep oeuvre Ohio all_right ominous desexualize prison_term waken misfire just nap',
#  'congratul ur award cd voucher guarant free entri wkli draw txt music tncs accolade four_hundred free_people force medicine',
#  'ranjith cal drpd deeraj deepak hold clutches',
#  'wen ur lovabl bcum angri wid dnt take serious coz angri childish n true way show deep affect care n luv kettoda manda nice day da direct infantile northward truthful agency demonstrate inscrutable regard fear northward prissy',
#  'doinghow',
#  'also ship compani take way usp take week get lag may bribe nipost get stuff likewise send direct agency direct workweek grow retardation corrupt grow pig_out',
#  'back lemm know readi binding bang',
#  'dont necessarili expect done get back though headin anticipate suffice grow binding',
#  'mmm yummi babe nice jolt suzi baby prissy saccade',
#  'lover need motive',
#  'tri contact repli offer video handset anytim network min unlimit text camcord repli call adjoin go video_recording French_telephone web Min_dialect call_option',
#  'i\x89û÷m park next mini come today think green side_by_side miniskirt fall now imagine',
#  'yup',
#  "anyway go shop cos sis done yet dun disturb liao in_any_case crack buy_at Centennial_State Systeme_International_d'Unites suffice heretofore grayish_brown upset Liao_dynasty",
#  'luton ring ur around h knell close_to atomic_number_1',
#  'hey realli horni want chat see nake text hot text charg unsubscrib text stop deficiency examine raging blockade',
#  'dint come us fall U.S.A.',
#  'wana plan trip sometm contrive trip-up',
#  'sure yet still tri get hold for_sure heretofore inactive grow clutches',
#  'ur rington servic chang free credit go choo content stop txt club stop po Chang_Jiang free_people acknowledgment crack mental_object blockade ball_club blockade United_States_Post_Office',
#  'evo download flash jealous flaunt',
#  'rington club get uk singl chart mobil week choo top qualiti rington messag free charg ball_club grow graph workweek superlative free_people',
#  'come mu sort narcot situat fall variety',
#  'night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay terminate fall limited agency grinning same Sunni_Islam light_beam downhearted downhearted alcove',
#  'hmv bonus special pound genuin hmv voucher answer easi question play send hmv info limited British_pound_sterling solution doubtfulness wager direct',
#  'usf guess might well take car guesswork mightiness intimately direct elevator_car',
#  'object bf come fall',
#  'thanx',
#  'tell rob mack gf theater separate hook macintosh house',
#  'awesom ill see bit ominous examine bite',
#  'sent type food like direct typewrite same',
#  'done hand celebr full swing yet suffice script total vacillation heretofore',
#  'got call tool grow call_option creature',
#  'wen miss someon misfire',
#  'ok ask money far all_right necessitate Former_Armed_Forces',
#  'oki',
#  'yeah think usual guy still pass last night get ahold anybodi let know ill throw yea imagine laugh_at inactive go_past endure grow Army_of_the_Righteous bang ominous bemuse',
#  'k might come tonight class let ear one_thousand mightiness fall course_of_instruction Army_of_the_Righteous auricle',
#  'ok all_right',
#  'hi babi cruisin girl friend r give call hour home alright fone fone love jenni xxx little_girl supporter gas_constant spring call_option minute abode all_right bang 30',
#  'life mean lot love life love peopl life world call friend call world ge life_story entail dish_out bang life_story bang life_story earthly_concern call_option supporter call_option earthly_concern Gaea',
#  'dearshal mail tonitebusi streetshal updat toniteth look okvarunnathu edukkukay raksha ollubut good one real sen chain_mail flavor just unrivaled real_number',
#  'hey told name gautham ah separate nominate',
#  'haf found feel stupid da v cam work witness spirit stupe quintet River_Cam oeuvre',
#  'oop got bit grow bite',
#  'much buzi a_lot',
#  'accid delet messag resend plea supplication',
#  'tmobil custom may claim free camera phone upgrad pay go sim card loyalti call end appli customs_duty title free_people tv_camera telephone_set earnings crack plug-in call_option terminate',
#  'unless situat go gurl would appropri crack',
#  'hurt tea make cri end life die plz keep one rose grave say stupid miss nice day bslvyl pain teatime build terminate life_story fail keep_open unrivaled grow inscribe pronounce stupe misfire prissy',
#  'cant pick phone right pls send messag cant_over pickax telephone_set rectify direct',
#  'need coff run tomoc believ time week alreadi motive endure prison_term workweek',
#  'awesom rememb last time got somebodi high first time diesel v endure prison_term grow richly kickoff prison_term diesel_engine quintet',
#  'shit realli shock scari cant imagin second def night think somewh could crash night save taxi jack scandalize cant_over indorsement imagine break_apart write hack',
#  'oh way food fridg want go meal tonight Ohio agency deficiency crack repast',
#  'womdar actor thespian',
#  'sms ac blind date aberdeen unit kingdom check sms blind date send hide samarium atomic_number_89 unsighted go_steady social_unit land check_up_on samarium unsighted go_steady direct enshroud',
#  'yup remb think book imagine',
#  'jos ask wana meet necessitate conform_to',
#  'lol yes friendship hang thread caus wont buy stuff friendly_relationship cling weave habit corrupt pig_out',
#  'themob check newest select content game tone gossip babe sport keep mobil fit funki text wap check_up_on Modern choice mental_object halting flavor chin-wagging baby mutant keep_open conform_to',
#  'garag key arent bookshelf distinguish',
#  'today accept dayu accept brother sister lover lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rpli mean enemi now take_on take_on comrade entail',
#  'think ur smart win å£ week week quiz text play nowtc winnersclub po box imagine chic advance workweek workweek test wager United_States_Post_Office',
#  'say hell give call friend got money hes definit buy end week pronounce sin spring call_option supporter grow helium corrupt terminate workweek',
#  'hi way normal waythi real ur uniquei hope know rest mylif hope find wot lost agency real_number desire bang residuum desire witness at_sea',
#  'made day great day build with_child',
#  'kkadvanc happi pongal',
#  'hmmm guess go kb n power yoga haha dunno tahan power yoga anot thk got lo oso forgot liao guesswork crack KiB northward force force grow draw_a_blank Liao_dynasty',
#  'realli dude friend afraid beau supporter',
#  'decemb mobil entitl updat latest colour camera mobil free call mobil updat co free late people_of_colour tv_camera free_people call_option Centennial_State free_people',
#  'coff cake guess patty guesswork',
#  'merri christma babe love ya kiss baby bang buss',
#  'hey dont go watch x men lunch haha crack vigil go humanity',
#  'cud tell ppl gona b bit cos buse hav gon past cos full still waitin pete x wad separate group_B bite Centennial_State past_tense Centennial_State total inactive go',
#  'would great well guild could meet bristol road somewh get touch weekend plan take flight good week with_child intimately lodge conform_to grow hint contrive direct escape just workweek',
#  'problem trouble',
#  'callsmessagesmiss call call_option',
#  'hi dahow today class now course_of_instruction',
#  'id say good sign well know track record read women pronounce just planetary_house intimately bang trail book translate char',
#  'cool text park nerveless green',
#  'read text sent meant joke read light translate direct think laugh translate ignitor',
#  'kkapo kgood movi',
#  'mayb could get book tomo return immedi someth grow recurrence',
#  'call germani penc per minut call fix line via access number prepay direct access call_option call_option desexualize pedigree get_at act get_at',
#  'chanc might evapor soon violat privaci steal phone number employ paperwork cool plea contact report supervisor mightiness before_long slip telephone_set act apply nerveless supplication adjoin written_report supervisory_program',
#  'valentin day special win å£ quiz take partner trip lifetim send go rcvd limited advance test direct spouse trip-up direct crack',
#  'tadaaaaa home babe still abode baby inactive',
#  'cool come havent wine dine nerveless fall vino',
#  'sleepingand surf channel-surf',
#  'sorri ill call later ominous call_option subsequently',
#  'call right call hand phone call_option rectify call_option script telephone_set',
#  'ok great thanx lot all_right with_child dish_out',
#  'take post come must text happi read one wiv hello carolin end favourit bless direct station fall mustiness translate unrivaled how-do-you-do terminate sign',
#  'hide stranger enshroud unknown',
#  'interest like pursuit same',
#  'sister clear two round birla soft yesterday clear_up II pear-shaped piano',
#  'gudnitetcpract go crack',
#  'dis yiju jus saw ur mail case huim havent sent num dis num examine chain_mail pillowcase direct',
#  'one small prestig problem unrivaled low trouble',
#  'fanci shag dointerest sextextukcom txt xxuk suzi txts cost per msg tncs websit x screwing toll monosodium_glutamate go',
#  'check realli miss see jeremiah great month check_up_on misfire examine Book_of_Jeremiah with_child',
#  'nah cant help ive never iphon cant_over help_oneself',
#  'car hour half go apeshit elevator_car minute one-half crack',
#  'today sorri day ever angri ever misbehav hurt plz plz slap urself bcoz ur fault basic good now always always pain bang geological_fault just',
#  'yo guy ever figur much need alcohol jay tri figur much safe spend weed laugh_at always a_lot motive intoxicant John_Jay a_lot rubber pass pot',
#  'ltgt ish minut minut ago wtf agone',
#  'thank callingforgot say happi onam sirjii fine rememb met insur personmeet qatar insha allahrakhesh ex tata aig join tisscotay pronounce all_right conform_to Katar_Peninsula old-fashioned conjoin',
#  'congratul ur award cd voucher guarant free entri wkli draw txt music tncs accolade four_hundred free_people force medicine',
#  'ur cashbal current pound maxim ur cashin send cash cc flow British_pound_sterling direct hard_currency millilitre',
#  'actor work work even sleep late sinc unemploy moment alway sleep late unemploy everi day saturday thespian oeuvre oeuvre fifty-fifty nap recently import nap recently Sabbatum',
#  'hello got st andrewsboy long way cold keep post how-do-you-do grow farsighted agency keep_open station',
#  'ha ha cool cool chikku chikkudb nerveless nerveless',
#  'oh ok prob Ohio all_right',
#  'check audrey status right check_up_on rectify',
#  'busi tri finish new year look forward final meet close Modern twelvemonth flavor send_on terminal conform_to',
#  'good afternoon sunshin dawn day refresh happi aliv breath air smile think love alway just refreshen hint broadcast grinning imagine bang',
#  'well know z take care worri intimately bang ezed direct fear',
#  'updatenow xmas offer latest motorola sonyericsson nokia free bluetooth doubl min txt orang call go late free_people Min_dialect orangutan call_option',
#  'discount code stop messag repli stop custom servic codification blockade blockade customs_duty',
#  'wat uniform get grow',
#  'cool text readi nerveless',
#  'hello boytoy geeee miss alreadi woke wish bed cuddl love how-do-you-do misfire waken regard bang bang',
#  'spoil bed well muff bang intimately',
#  'go bath msg next ltgt min crack bathtub monosodium_glutamate side_by_side Min_dialect',
#  'cant keep talk peopl sure pay agr price pls tell want realli buy much pay cant_over keep_open verbalize for_sure earnings toll separate deficiency corrupt a_lot earnings',
#  'thank rington order refer charg gbp per week unsubscrib anytim call custom servic say have-to_doe_with workweek call_option customs_duty',
#  'say happen pronounce materialise',
#  'could seen mei didt recogni face examine cheek',
#  'well lot thing happen lindsay new year sigh bar ptbo blue heron someth go intimately dish_out materialise Vachel_Lindsay Modern twelvemonth suspire blockade downhearted crack',
#  'keep payasam rinu bring keep_open wreak',
#  'taught ranjith sir call sms like becaus hes verifi project prabu told today pa dont mistak instruct call_option samarium same helium cast separate now protactinium',
#  'guess worri must know way bodi repair quit sure shouldnt worri well take slow first test guid ovul relax noth youv said reason worri ill keep followin guesswork mustiness bang agency amend throw_in_the_towel for_sure intimately direct dense kickoff examine decompress aforementioned rationality ominous keep_open',
#  'yeah sure give coupl minut track wallet yea for_sure spring trail pocketbook',
#  'hey leav big deal take care self-aggrandizing grapple direct fear',
#  'hey late ah meet recently conform_to',
#  'doubl min txts free bluetooth orang avail soni nokia motorola phone call Min_dialect free_people orangutan help telephone_set call_option',
#  'took mr owl lick direct hooter figure_out',
#  'custom place call customs_duty station call_option',
#  'mm time dont like fun prison_term same merriment',
#  'half price orang line rental latest camera phone free phone call mobilesdirect free updat one-half toll orangutan pedigree late tv_camera telephone_set free_people telephone_set call_option free_people',
#  'yup lunch buffet eat alreadi sideboard eat_up',
#  'huh late fr dinner recently atomic_number_87',
#  'hey sat go intro pilat kickbox Sabbatum crack presentation',
#  'morn ok all_right',
#  'yes think offic lap room think last day didnt shut imagine elbow_room imagine endure shut_out',
#  'pick bout time go pickax turn prison_term crack',
#  'perform award calcul everi two monthnot current one month period do accolade II flow unrivaled time_period',
#  "actual sleep still might call back text rock sis send text wen wake real nap inactive mightiness call_option binding John_Rock Systeme_International_d'Unites direct waken",
#  'alway put busi put pictur ass facebook one open peopl ive ever met would think pictur room would hurt make feel violat set set stern unrivaled always conform_to imagine elbow_room pain build spirit',
#  'good even sir al salam wahleykkumshar happi newsbi grace god got offer tayseertissco joinedhop fineinshah allahmeet sometimerakheshvisitor india just fifty-fifty Camellia_State adorn grow go Bharat',
#  'hmmmkbut want chang field quick dai wanna get system administr network administr deficiency Chang_Jiang discipline grow organisation web',
#  'free rington text first poli text get true tone help free tone £ eå£nd txt stop free_people kickoff grow truthful flavor help_oneself free_people flavor blockade',
#  'dear chechi talk verbalize',
#  'hair cream ship fuzz skim send',
#  'none happen til get though materialise grow',
#  'yep great loxahatch xmas tree burn ltgt start hour with_child shoetree burn_down kickoff minute',
#  'haha get use drive usf man know lot stoner grow habit force humanity bang dish_out stone',
#  'well slight disastr class pm fav darl hope day ok coff wld good cant stay late tomorrow time place alway intimately slim course_of_instruction phase_modulation desire all_right just cant_over stoppage recently prison_term station',
#  'hello good week fanci drink someth later how-do-you-do just workweek pledge subsequently',
#  'headin toward busetop',
#  'messagesom text miss sendernam miss number miss sentdat miss miss lot everyth miss sent via fullonsmscom misfire misfire act misfire misfire misfire dish_out misfire direct',
#  'come room point iron plan weekend fall elbow_room direct Fe contrive',
#  'cos want thing Centennial_State deficiency',
#  'oki ill go yan jiu skip ard oso go cine den go mrt one blah blah blah ominous crack skim crack hideout crack unrivaled claptrap claptrap claptrap',
#  'bring home wendi wreak abode',
#  'date servic call go_steady call_option',
#  'whatsup dont want sleep deficiency nap',
#  'alright new goal all_right Modern',
#  'free entri å£ week competit text word win tc free_people workweek advance atomic_number_43',
#  'alright ill head minut text meet all_right ominous direct conform_to',
#  'send logo ur lover name join heart txt love mobno eg love adam eve yahoo txtno ad direct logotype nominate conjoin nub bang bang go evening hick advertizement',
#  'yesfrom last week take live call endure workweek direct endure call_option',
#  'someon contact date servic enter phone fanci find call landlin adjoin go_steady get_in telephone_set witness call_option',
#  'siva hostel aha Shiva inn',
#  'urgent mobil number award å£ prize guarant call land line claim valid pressing act accolade lever call_option bring pedigree title',
#  'send ur friend receiv someth ur voic speak express attitud ltgt irrit ltgt lovabl repli direct supporter verbalize',
#  'ok shell ok guess all_right racing_shell all_right guesswork',
#  'aathiwh dear',
#  'pain urin thing el infliction elevated_railroad',
#  'esplanad ì mind give lift cos got car today nous spring wind Centennial_State grow elevator_car now',
#  'wnt buy bmw car urgentlyit vri urgentbut hv shortag ltgt lacsther sourc arng dis amt ltgt lacsthat prob corrupt elevator_car',
#  'home watch tv lor abode vigil telly',
#  'usual take fifteen fuck minut respond yes question direct bang doubtfulness',
#  'congrat nokia video camera phone call call cost ave call vari mobil close post ldn video_recording tv_camera telephone_set call_option call_option toll call_option confining station',
#  'book ticket pongal fine',
#  'avail like right around hillsborough amp ltgt th help same rectify close_to thorium',
#  'messag sent askin ltgt dollar shoul pay ltgt ltgt direct one_dollar_bill earnings',
#  'ask g iouri ive told stori like ten time alreadi necessitate gm separate same x prison_term',
#  'long appleb fuck take farsighted bang direct',
#  'hi hope get txtjourney hasnt gdnow min late think desire grow Min_dialect recently imagine',
#  'like love arrang same bang',
#  'yesh realli greatbhaji told kalli best cricket sachin worldveri tough get separate Charles_Herbert_Best rugged grow',
#  'suppo wake gt waken',
#  'oic saw tot din found group liao examine toddler clamor witness chemical_group Liao_dynasty',
#  'sorri ill call later ominous call_option subsequently',
#  'hey hey wereth monkeespeopl say monkeyaround howdi gorgeous pronounce',
#  'sorri batteri die come get gram place fail fall grow gm station',
#  'well done blimey exerci yeah kinda rememb wot hmm intimately suffice yea kind_of',
#  'wont get concentr dear know mind everyth habit grow bang nous',
#  'lol made plan new year build contrive Modern twelvemonth',
#  'min later k Min_dialect subsequently one_thousand',
#  'hank lotsli',
#  'thank hope good day today desire just now',
#  'kkwhat detail want transferacc enough item deficiency adequate',
#  'ok tell stay yeah tough optimist thing improv month all_right separate stoppage yea rugged',
#  'loan purpo å£ å£ homeown tenant welcom previous refus still help call free text back help loanword inactive help_oneself call_option free_people binding help_oneself',
#  "si si think ill go make oreo truffl Systeme_International_d'Unites Systeme_International_d'Unites imagine ominous crack build oreo_cookie",
#  'look ami ure beauti intellig woman like lot know donåõt like like donåõt worri flavor char same dish_out bang same same',
#  'hope result consist intellig kind start ask practicum link keep ear open best ttyl desire solution dwell variety kickoff necessitate connexion keep_open auricle Charles_Herbert_Best',
#  'call cost guess isnt bad miss ya need ya want ya love ya call_option toll guesswork misfire motive deficiency bang',
#  'go thru differ feelingwav deci cope individualtim heal everyth believ crack disagree grapple bring_around',
#  'go phone gonna die stay crack telephone_set fail stoppage',
#  'great never better day give even reason thank god with_child punter spring fifty-fifty rationality',
#  'upgrdcentr orang custom may claim free camera phone upgrad loyalti call offer end juli tcs appli optout avail orangutan customs_duty title free_people tv_camera telephone_set call_option go terminate atomic_number_43 help',
#  'sorri ill call later ok bye ominous call_option subsequently all_right adieu',
#  'ok way railway all_right agency railway_line',
#  'great princess love give receiv oral doggi style fave posit enjoy make love ltgt time per night with_child bang spring viva_voce title fix love build bang prison_term',
#  'dont put stuff road keep get slipperi set pig_out keep_open grow',
#  'go ride bike crack devolve_on wheel',
#  'yup need ill jus wait e rain stop motive ominous delay east rain_down blockade',
#  'mani compani tell languag separate',
#  'okmail dear dave final notic collect tenerif holiday cash award call landlin tcs sae terminal hard_currency accolade call_option atomic_number_43',
#  'long sinc scream princess farsighted cry',
#  'noth meant money enter account bank remov flat rate someon transfer ltgt account ltgt dollar got remov bank differ charg also differb sure trust person send account detail cos think get_in invoice money_box carry-over invoice one_dollar_bill grow money_box disagree likewise for_sure desire somebody direct invoice item Centennial_State',
#  'want get laid tonight want real dog locat sent direct ur mob join uk largest dog network txting moan deficiency grow deficiency real_number blackguard direct jam conjoin with_child blackguard web groan',
#  'nice line said broken heart plz dont cum time infront wise trust good prissy pedigree aforementioned rugged nub prison_term heady desire just',
#  'ok gonna head usf like fifteen minut all_right direct same',
#  'love aathilov lot bang dish_out',
#  'tension ahwhat machiani problem trouble',
#  'k pick anoth done one_thousand pickax suffice',
#  'whenr guy get back g said think stay mcr laugh_at grow binding gm aforementioned imagine stoppage',
#  'almost see sec most examine Securities_and_Exchange_Commission',
#  'yo carlo friend alreadi ask work weekend supporter necessitate oeuvre',
#  'watch tv lor vigil telly',
#  'thank babi cant wait tast real thing cant_over delay real_number',
#  'chang fb jaykwon thuglyf falconerf Chang_Jiang',
#  'win realli side long time advance incline farsighted prison_term',
#  'free messag activ free text messag repli messag word free term condit visit free_people free_people free_people terminal_figure travel_to',
#  'dear reach railway happen get_to railway_line materialise',
#  'depend qualiti want type sent boy fade glori want ralph mayb deficiency typewrite direct wither deficiency',
#  'think ive fix send test messag imagine desexualize direct examine',
#  'sorri man account dri would want could trade back half could buy shit credit card humanity invoice deficiency business_deal binding one-half corrupt jack acknowledgment plug-in',
#  'congrat year special cinema pass call suprman v etc free dont miss twelvemonth limited go_past call_option quintet free_people misfire',
#  'sorryin meet ill call later conform_to ominous call_option subsequently',
#  'class ltgt reunion course_of_instruction',
#  'free nowcan call free_people call_option',
#  'got meh grow',
#  'nope think go monday sorri repli late imagine crack recently',
#  'told accentur confirm true separate substantiate truthful',
#  'kate jackson rec center right Michael_Joe_Jackson concentrate rectify',
#  'dear reach room get_to elbow_room',
#  'fight world easi either win lose bt fightng close dificult lose lose win still lose battle earthly_concern advance suffer confining suffer suffer advance inactive suffer',
#  'ì come fall',
#  'check nuerologist check_up_on',
#  'lolnic went fish water endure water_supply',
#  'congratul week competit draw å£ prize claim call tcsstop sms workweek force lever title call_option samarium',
#  'wait e car dat bore wat cos wait outsid got noth home stuff watch tv wat delay east elevator_car endure Centennial_State delay grow abode pig_out vigil telly',
#  'mayb westshor hyde park villag place near hous green station most',
#  'know anthoni bring money ive school fee pay rent stuff like need help friend need bang wreak school_day earnings charter pig_out same motive help_oneself supporter motive',
#  'signif',
#  'opinion jada kusruthi lovabl silent spl charact matur stylish simpl pls repli sentiment tacit fashionable',
#  'latest gs still scroung ammo want give new ak tri late gm inactive deficiency spring Modern Alaska',
#  'prabhaim sorydarealyfrm heart sori nub sorus',
#  'lol ok forgiven all_right forgive',
# ...
#  'tri contact offer new video phone anytim network min half price rental camcord call repli deliveri wed adjoin go Modern video_recording telephone_set web Min_dialect one-half toll call_option conjoin',
#  'last chanc claim ur å£ worth discount voucherstext yes nowsavamobmemb offer mobil cs å£ sub remov txt x stop endure title go nose_candy submarine go blockade',
#  'luv soo much donåõt understand special r ring luv xxx a_lot translate limited gas_constant knell 30',
#  'pls send comprehen mail pay much direct chain_mail earnings a_lot',
#  'prashanthettan mother pass away last night pray famili female_parent go_past forth endure',
#  'urgent call landlin complimentari ibiza holiday cash await collect sae tcs po box ppm pressing call_option hard_currency wait atomic_number_43 United_States_Post_Office',
#  'kkwhen go crack',
#  'meanwhil shit suit xavier decid give us ltgt second warn samantha come play jay guitar impress shit also dont think doug realiz dont live anymor jack beseem spring U.S.A. indorsement discourage fall wager John_Jay yarn-dye jack likewise imagine endure',
#  'stomach thru much trauma swear cant eat better lose weight endure a_lot depose cant_over eat_up punter suffer weightiness',
#  'officewhat mattermsg nowi call break call_option happy_chance',
#  'yeah bare enough room two us x mani fuck shoe sorri man see later yea unornamented adequate elbow_room II U.S.A. go bang horseshoe humanity examine subsequently',
#  'today offer claim ur å£ worth discount voucher text yes savamob member offer mobil cs å£ sub unsub repli x now go title appendage go nose_candy submarine go',
#  'reach orchard alreadi wan go buy ticket first get_to grove pale crack corrupt fine kickoff',
#  'real babi want bring inner tigress real_number deficiency wreak',
#  'da run activ full version da endure total reading',
#  'ah poor babyhop urfeel bettersn luv probthat overdo work hey go care spk sn lot lovejen xxx hapless exaggerate oeuvre crack fear dish_out 30',
#  'stop stori ive told ive return hes say order blockade separate recurrence helium pronounce say',
#  'talk sexi make new friend fall love world discreet text date servic text vip see could meet verbalize build Modern supporter drop bang earthly_concern circumspect go_steady panjandrum examine conform_to',
#  'go take babe crack direct baby',
#  'hai ana tomarrow come morn ltdecimalgt ill sathi go rto offic repli came home fall ominous crack fall abode',
#  'spoon okay smooch all_right',
#  'say somebodi name tampa pronounce nominate',
#  'work go min oeuvre crack Min_dialect',
#  'brother genius comrade',
#  'sorri guess whenev get hold connect mayb hour two ill text guesswork grow clutches tie_in minute II ominous',
#  'find time bus coz need sort stuff witness prison_term motive variety pig_out',
#  'dude ive see lotta corvett late beau examine recently',
#  'congratul ur award either yrs suppli cds virgin record mysteri gift guarant call tscs å£ approx accolade twelvemonth four_hundred vestal book empower call_option',
#  'consid wall bunker shit import never play peac guess place high enough dont matter bulwark sand_trap jack wager guesswork station richly adequate weigh',
#  'privat account statement xxxxxx show unredeem point call identifi code expir invoice assertion demonstrate direct call_option codification',
#  'hello need posh bird chap user trial prod champney put need address dob asap ta r how-do-you-do motive swish raspberry crack drug_user tryout goading set motive direct atomic_number_73 gas_constant',
#  'want xmas free text messag new video phone half price line rental call free find deficiency free_people Modern video_recording telephone_set one-half toll pedigree call_option free_people witness',
#  'well offici philosoph hole wanna call home readi save intimately pickle call_option abode write',
#  'go goodno problembut still need littl experi understand american custom voic crack inactive motive translate customs_duty',
#  'ill text drop x ominous drop_curtain go',
#  'ugh long day exhaust want cuddl take nap farsighted use_up deficiency direct forty_winks',
#  'talk atleast day otherwi miss best friend world shakespear shesil ltgt verbalize misfire Charles_Herbert_Best supporter earthly_concern',
#  'shop till drop either å£ cash å£ travel voucher call ntt po box fixedlin cost mobil vari buy_at money_box drop_curtain hard_currency go call_option United_States_Post_Office toll',
#  'castor need see someth Alpha_Geminorum motive examine',
#  'sunshin quiz wkli q win top soni dvd player know countri liverpool play mid week txt ansr å£ sptyron test advance superlative thespian bang wager workweek',
#  'secret admir look make contact ufind rreveal think ur specialc mystical flavor build adjoin imagine',
#  'secret admir look make contact ufind rreveal think ur specialc mystical flavor build adjoin imagine',
#  'remind download content alreadi paid goto mymobi tv collect content cue mental_object pay_off telly mental_object',
#  'see knew give break time woul lead alway want miss curfew gonna gibe til one midnight movi gonna get til need come home need getsleep anyth need b studdi ear train examine bang spring happy_chance prison_term direct deficiency misfire unrivaled grow motive fall abode motive motive group_B auricle direct',
#  'love give massag use lot babi oil fave posit bang spring habit dish_out fossil_oil fix',
#  'dude go sup beau crack swallow',
#  'yoyyooo know chang permiss drive mac usb flash drive bang Chang_Jiang force macintosh flaunt force',
#  'gibb unsoldmik hussey',
#  'like talk pa abl dont know same verbalize protactinium bang',
#  'dun cut short leh dun like ah fail shes quit sad grayish_brown abbreviate brusque grayish_brown same go_wrong throw_in_the_towel lamentable',
#  'unbeliev faglord',
#  'wifehow knew time murder exact bang prison_term off accurate',
#  'ask princess necessitate',
#  'great princess think with_child imagine',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie wacko stonecutter',
#  'ok noe ure busi realli bore msg oso dunno wat colour choo one all_right endure monosodium_glutamate people_of_colour unrivaled',
#  'doesnt g class ear tomorrow thus shouldnt tri smoke ltgt gm course_of_instruction auricle bullet',
#  'superb thought grate dont everyth want mean still opportun happier tomorrow today brilliant imagine deficiency entail inactive happy now',
#  'hope good week check desire just workweek check_up_on',
#  'use hope agent dont drop sinc ive book thing year whole boston nyc experi habit desire agentive_role drop_curtain twelvemonth solid Hub_of_the_Universe',
#  'thursday night yeah sure thing well work yea for_sure intimately oeuvre',
#  'free rington wait collect simpli text password mix verifi get usher britney fml free_people delay word grow James_Ussher',
#  'probabl money worri thing come due sever outstand invoic work two three month ago fall ascribable lop oeuvre II leash agone',
#  'possibl teach',
#  'wonder phone batteri went dead tell love babe telephone_set endure beat separate bang baby',
#  'love smell bus aint tobacco bang odor',
#  'get worri derek taylor alreadi assum worst grow Zachary_Taylor defective',
#  'hey charl sorri late repli recently',
#  'lastest stereophon marley dizz racal libertin stroke win nookii game flirt click themob wap bookmark text wap terminal throw advance halting coquetry penetrate',
#  'ill give plus said grinul greet whenev speak ominous spring aforementioned recognize verbalize',
#  'white fudg oreo store blank oreo_cookie',
#  'januari male sale hot gay chat cheaper call nation rate cheap peak stop text call manlike cut-rate_sale raging festal sleazy call_option land sleazy superlative blockade call_option',
#  'love come took long leav zaher got word ym happi see sad left miss bang fall direct farsighted grow examine lamentable remaining misfire',
#  'sorri hurt pain',
#  'cant feel nauseous piss didnt eat sweet week caus today plan pig diet week hungri cant_over spirit urine eat_up dessert workweek now contrive grunter workweek',
#  'ok lor ear still project meet all_right auricle inactive cast conform_to',
#  'call da wait call call_option delay call_option',
#  'could ask carlo could get anybodi el chip necessitate grow elevated_railroad flake',
#  'actual send remind today wonder weekend real direct cue now',
#  'peopl see msgs think iam addict msging wrong bcoz dont know iam addict sweet friend bslvyl examine monosodium_glutamate imagine hook haywire bang hook dessert supporter',
#  'hey gave photo regist drive ah tmr wanna meet yck move_over pic force conform_to',
#  'dont talk ever ok word verbalize always all_right',
#  'wana see examine',
#  'way school pls send ashley number agency school_day direct act',
#  'shall fine avalarr hollalat all_right',
#  'went attend anoth two round todaybut still didt reach home endure take_care II pear-shaped inactive get_to abode',
#  'actual delet old websitenow blog magicalsongsblogspotcom real one-time web_log',
#  'k wait chikkuil send aftr ltgt min one_thousand delay direct Min_dialect',
#  'diet ate mani slice pizza yesterday ugh alway diet eat_up slash',
#  "ki give kvb acc detail ch'i spring item",
#  'oh come ah Ohio fall',
#  'money r lucki winner claim prize text money å£ give away text rate gas_constant success title lever spring forth',
#  'realli sorri wont b abl fridayhop find alternativehop yr term go ok habit group_B witness twelvemonth terminal_figure crack all_right',
#  'congratul ore mo owo wa enjoy wish mani happi moment fro wherev go second love regard import crack',
#  'samus shoulder yet heretofore',
#  'time think youll need know near campus prison_term imagine motive bang most',
#  'dear matthew plea call landlin complimentari tenerif holiday å£ cash await collect sae tcs Saint_Matthew_the_Apostle supplication call_option hard_currency wait atomic_number_43',
#  'dun wear jean lor grayish_brown endure',
#  'sinc side fever vomitin incline pyrexia',
#  'kkare colleg',
#  'urgent call landlin complimentari tenerif holiday å£ cash await collect sae tcs box pressing call_option hard_currency wait atomic_number_43',
#  'better made friday stuf like pig yesterday feel bleh least writh pain kind bleh punter build Fri same grunter spirit to_the_lowest_degree infliction variety',
#  'sell well ton coin sell coin someon thru paypal voila money back life pocket betray intimately net_ton mint betray mint binding life_story air_hole',
#  'theyr lot place hospit medic place safe dish_out station medical_officer station rubber',
#  'get touch folk wait compani txt back name age opt enjoy communiti grow hint folk_music delay binding nominate get_on love',
#  'also ive sorta blown coupl time recent id rather text blue look weed likewise muff prison_term Holocene instead downhearted flavor pot',
#  'sent score sopha secondari applic school think think appli research cost also contact joke ogunrind school one less expen one direct scotch school_day imagine imagine inquiry toll likewise adjoin laugh school_day unrivaled to_a_lesser_extent unrivaled',
#  'cant wait see photo use cant_over delay examine pic habit',
#  'ur cashbal current pound maxim ur cashin send go cc po box flow British_pound_sterling direct crack millilitre United_States_Post_Office',
#  'hey book kb sat alreadi lesson go ah keep sat night free need meet confirm lodg KiB Sabbatum crack keep_open Sabbatum free_people motive conform_to substantiate',
#  'chk ur belovd ms dict one_thousand',
#  'time want come prison_term deficiency fall',
#  'awesom lemm know whenev around bang close_to',
#  'shb b ok lor thanx group_B all_right',
#  'beauti truth graviti read care heart feel light someon feel heavi someon leav good night accuracy translate fear nub spirit ignitor spirit just',
#  'also rememb get dobbi bowl car likewise grow arena elevator_car',
#  'filthi stori girl wait little_girl delay',
#  'sorri ur msg yar lor poor thing one night tmr ull brand new room sleep monosodium_glutamate hapless unrivaled Ullr firebrand Modern elbow_room nap',
#  'love isnt deci feel could decid love life would much simpler less magic bang spirit bang life_story a_lot bare to_a_lesser_extent sorcerous',
#  'welp appar retir',
#  'sort code acc bank natwest repli confirm ive sent right person variety codification money_box substantiate direct rectify somebody',
#  '',
#  'sure cant take sick time for_sure cant_over direct cast prison_term',
#  'urgent tri contact today draw show å£ prize guarant call land line claim pressing adjoin now force demonstrate lever call_option bring pedigree title',
#  'watch cartoon listen music amp eve go templ amp church vigil medicine evening crack Christian_church',
#  'yo chad gymnast class wanna take site say christian class full course_of_instruction direct internet_site pronounce course_of_instruction total',
#  'much buzi a_lot',
#  'better still catch let ask sell ltgt punter inactive apprehension Army_of_the_Righteous necessitate betray',
#  'sure night menu know noon menu for_sure card bang midday card',
#  'want come backa beauti necklac token heart youthat give wife likingb seeno one give thatdont call mei wait till come deficiency fall tokenish nub spring married_woman unrivaled spring call_option delay money_box fall',
#  'go aptitud class crack course_of_instruction',
#  'wont b tri sort hous ok habit group_B variety all_right',
#  'yar lor wan go hor race today mah eat earlier lor ate chicken rice pale crack wash now eat_up before eat_up Gallus_gallus Elmer_Reizenstein',
#  'haha awesom omw back binding',
#  'yup thk e shop close lor east buy_at confining',
#  'account number invoice act',
#  'eh send wrong lar direct haywire',
#  'hey ad crap nite borin without ya boggi bore biatch thanx wait til nxt time il ave ya advertizement bullshit endure delay prison_term 49',
#  'ok shall talk all_right verbalize',
#  'dont hesit know second time weak like keep notebook eat day anyth chang day sure noth bang indorsement prison_term imperfect same keep_open eat_up Chang_Jiang for_sure',
#  'hey pay salari de ltgt earnings Delaware',
#  'anoth month need chocol weed alcohol motive pot intoxicant',
#  'start search get job daysh great potenti talent kickoff hunting grow subcontract with_child natural_endowment',
#  'reckon need town eightish walk carpark imagine motive walk_of_life',
#  'congrat mobil videophon r call videochat wid mate play java game dload polyph music nolin rentl gas_constant call_option spouse wager halting medicine',
#  'look fuckin time fuck think flavor prison_term bang imagine',
#  'yo guess drop guesswork drop_curtain',
#  'carlo say hell mu ltgt minut pronounce sin',
#  'offic call ltgt min call_option Min_dialect',
#  'geeee miss alreadi know think fuck cant wait till next year togeth love kiss misfire bang imagine bang cant_over delay money_box side_by_side twelvemonth bang buss',
#  'yun ahth ubi one say ì wan call tomorrowc look iren got ubi cresubi tech daysì¬n unrivaled pronounce pale call_option flavor grow technical_school',
#  'ugh gotta drive back sd la butt sore force binding Pelican_State stern afflictive',
#  'juli',
#  'hi relax time ever get everi day parti good night get home tomorrow decompress prison_term always grow just grow abode',
#  'ì ìï wan come come lor din stripe skirt pale fall fall clamor streak fudge',
#  'xmas stori peac xmas msg love xmas miracl jesus hav bless month ahead amp wish merri xmas monosodium_glutamate bang sign leading regard',
#  'cant dont number cant_over act',
#  'chang e one next escal Chang_Jiang east unrivaled side_by_side',
#  'yetund class run water make ok pls course_of_instruction endure water_supply build all_right',
#  'lot happen feel quiet beth aunt char work lot helen mo dish_out materialise spirit calm charr oeuvre dish_out Helen_of_Troy second',
#  'ì wait bus stop aft ur lect lar dun ì go get car come back n pick ì delay blockade grayish_brown crack grow elevator_car fall binding northward pickax',
#  'aight thank comin',
#  ...]

# %%
#Word Embeddings: GloVe

# %%
texts = docs_expansion

# %% [markdown]
# # GLOVE

# %%
# !pip install Tokenizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Tokenizer
#   Downloading tokenizer-3.4.1-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 3.3 MB/s
# Installing collected packages: Tokenizer
# Successfully installed Tokenizer-3.4.1

# %%
# Calculate the length of our vocabulary
from keras.preprocessing.text import Tokenizer
word_tokenizer = Tokenizer()

# %%
word_tokenizer.fit_on_texts(texts)

vocab_length = len(word_tokenizer.word_index) + 1
vocab_length
# Out:
# 7998

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import tensorflow as tf
def embed(corpus): 
    return word_tokenizer.texts_to_sequences(corpus)

# %%
longest_train = max(texts, key=lambda sentence: len(word_tokenize(sentence)))
length_long_sentence = len(word_tokenize(longest_train))

train_padded_sentences = tf.keras.preprocessing.sequence.pad_sequences(
    embed(texts), 
    length_long_sentence, 
    padding='post'
)

X = train_padded_sentences

# %%
print(X)
# Out:
# [[   4 4202  496 ...    0    0    0]
#  [  23  444  869 ...    0    0    0]
#  [   8  624  944 ...    0    0    0]
#  ...
#  [7996 1531 7997 ...    0    0    0]
#  [ 283 1867  119 ...    0    0    0]
#  [2802  636  335 ...    0    0    0]]

# %% [markdown]
# # TFIDF
# Menghitung TF IDF untuk setiap dokumen dan hasilnya digunakan untuk clustering dokumen

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfTransformer

transformer = TfidfTransformer(smooth_idf=False)
tfidf = transformer.fit_transform(X)
print(tfidf.shape )
# Out:
# (5572, 114)
